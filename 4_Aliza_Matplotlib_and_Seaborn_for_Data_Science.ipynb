# %% [markdown]
# <a href="https://colab.research.google.com/github/alizasultanaesd-png/skill-morph-work/blob/main/4_Aliza_Matplotlib_and_Seaborn_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages (run this first in Google Colab)
# !pip install numpy pandas matplotlib seaborn

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Upload: StudentsPerformance.csv and gym_membership.csv

# Load data
gym = pd.read_csv('gym_membership.csv')
# Out:
#      <input type="file" id="files-aac16e68-a415-4fef-b79b-950546a8bc4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aac16e68-a415-4fef-b79b-950546a8bc4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

# %%
member = pd.read_csv('/content/gym_membership.csv')

# %% [markdown]
# ## **Understand the Data**

# %%
# Check data
print(member.head())
print(member.shape)
print(member.columns.tolist())
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
# 3   4    Male  1980-04-12   44        Premium               3
# 4   5    Male  1980-09-10   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                         NaN
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
print("\nDataFrame Description:")
print(member.describe())
# Out:
# DataFrame Description:
#                 id          Age  visit_per_week  avg_time_in_gym
# count  1000.000000  1000.000000     1000.000000      1000.000000
# mean    500.500000    30.604000        2.682000       105.260000
# std     288.819436    10.817958        1.241941        43.557177
# min       1.000000    12.000000        1.000000        30.000000
# 25%     250.750000    21.000000        2.000000        67.000000
# 50%     500.500000    30.000000        3.000000       104.000000
# 75%     750.250000    40.000000        3.000000       143.000000
# max    1000.000000    49.000000        5.000000       180.000000

# %%
# Basic DataFrame information
print("\nDataFrame Info:")
print(member.info())

# %%
# Display last 5 rows
print("\nLast 5 rows of the dataset:")
print(member.tail())
# Check data types
print("\nData Types:")
print(member.dtypes)
# Out:
# Last 5 rows of the dataset:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 995   996  Female  1984-09-22   40       Standard               3
# 996   997  Female  2008-11-19   15       Standard               3
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 995       Thu, Tue, Wed                False              NaN
# 996       Fri, Mon, Sun                 True     XCore, Zumba
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 995          20:56:00           22:42:00              106      False
# ...

# %%
# Install required packages (run this first in Google Colab)
# !pip install numpy pandas matplotlib seaborn

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Upload: StudentsPerformance.csv and gym_membership.csv

# Load data
gym = pd.read_csv('gym_membership.csv')

# %%
member = pd.read_csv('/content/gym_membership.csv')

# %% [markdown]
# # **Bar Chart**

# %%
# 1. Bar chart of gym membership types
import pandas as pd
member = pd.read_csv('gym_membership.csv')
member_count = member['abonoment_type'].value_counts()
plt.bar(member_count.index, member_count.values, color=['pink', 'blue'])
plt.title('Gym Membership Types')
plt.xlabel('Membership Type')
plt.ylabel('Number of Members')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True, which="both", linestyle="-", linewidth=0.7, alpha=0.7)
#plt.savefig("/content/drive/MyDrive/datasets/colorbarchartgendervalue.png",dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # **Scatter Plot**

# %%
# 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])

plt.figure(figsize=(8, 5))
plt.scatter(gym['Age'], gym['visit_per_week'], color='teal', alpha=0.6, edgecolors='w')
plt.title("Age vs Weekly Gym Visits")
plt.xlabel("Age")
plt.ylabel("Visits per Week")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Histogram**

# %%
# 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])

# Math score distribution
plt.hist(gym['avg_time_in_gym'], bins=15, color='mediumseagreen', edgecolor='black')
plt.title("Distribution of Average Time Spent in Gym")
plt.xlabel("Time in Gym (minutes)")
plt.ylabel("Number of Members")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Multiple Plots**

# %%
# Create 2x2 grid
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
sns.set_style("whitegrid")

# Plot 1: Age distribution (Histogram)
sns.histplot(gym['Age'], bins=15, kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title("Age Distribution")
axes[0, 0].set_xlabel("Age")
axes[0, 0].set_ylabel("Count")

# Plot 2: Gender count (Countplot)
sns.countplot(data=gym, x='gender', ax=axes[0, 1], palette='pastel')
axes[0, 1].set_title("Gender Count")
axes[0, 1].set_xlabel("Gender")
axes[0, 1].set_ylabel("Number of Members")

# Plot 3: Visits per week (Histogram)
sns.histplot(gym['visit_per_week'], bins=10, ax=axes[1, 0], color='lightgreen')
axes[1, 0].set_title("Visits per Week")
axes[1, 0].set_xlabel("Visits")
axes[1, 0].set_ylabel("Count")

# Plot 4: Personal training (Countplot)
sns.countplot(data=gym, x='personal_training', ax=axes[1, 1], palette='coolwarm')
axes[1, 1].set_title("Personal Training Participation")
axes[1, 1].set_xlabel("Personal Training")
axes[1, 1].set_ylabel("Number of Members")

plt.tight_layout()
#plt.savefig("/content/drive/MyDrive/datasets/multipleplot.png",dpi=300)
plt.show()

# %% [markdown]
# # **Seaborn**

# %% [markdown]
# # **Box Plot**

# %%
# 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')

plt.figure(figsize=(7, 5))
sns.boxplot(data=gym, x='gender', y='Age')
plt.title("Age Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Age")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Count Plot**

# %%
# 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')


sns.countplot(data=gym, x='days_per_week', order=order)
sns.countplot(data=gym, x='days_per_week', palette='coolwarm')
plt.title("Frequency of Gym Visits per Week")
plt.xlabel("Days per Week")
plt.ylabel("Number of Members")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Bar Plot with Average**

# %%
# 3. Bar plot: Average visits by membership type # Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')

sns.barplot(data=gym, x='abonoment_type', y='visit_per_week', palette='viridis')
plt.title("Average Weekly Visits by Membership Type")
plt.xlabel("Membership Type")
plt.ylabel("Average Visits per Week")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Gym Data Exploration**

# %%
# 1. Age distribution (Histogram)
sns.histplot(gym['Age'], bins=15, kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title("Age Distribution")
axes[0, 0].set_xlabel("Age")
axes[0, 0].set_ylabel("Count")

# 2. Gender count (Countplot)
sns.countplot(data=gym, x='gender', ax=axes[0, 1], palette='pastel')
axes[0, 1].set_title("Gender Count")
axes[0, 1].set_xlabel("Gender")
axes[0, 1].set_ylabel("Number of Members")

# 3. Visits per week (Histogram)
sns.histplot(gym['visit_per_week'], bins=10, ax=axes[1, 0], color='lightgreen')
axes[1, 0].set_title("Visits per Week")
axes[1, 0].set_xlabel("Visits")
axes[1, 0].set_ylabel("Count")

# 4. Personal training (Countplot)
sns.countplot(data=gym, x='personal_training', ax=axes[1, 1], palette='coolwarm')
axes[1, 1].set_title("Personal Training Participation")
axes[1, 1].set_xlabel("Personal Training")
axes[1, 1].set_ylabel("Number of Members")

# Final layout adjustment
plt.tight_layout()
plt.show()

# %%
# Gym data

# Display last 5 rows

# Check data types

# %%
# Task 1: Basic Matplotlib (3 plots)
# 1. Bar chart of gym membership types
# Use: gym['abonoment_type'].value_counts()

# 2. Histogram of time in gym
# Use: plt.hist(gym['avg_time_in_gym'])

# 3. Scatter plot: Age vs visits per week
# Use: plt.scatter(gym['Age'], gym['visit_per_week'])

# %%
# 1. Box plot: Gender vs Age
# Use: sns.boxplot(data=gym, x='gender', y='Age')

# 2. Count plot: Days per week
# Use: sns.countplot(data=gym, x='days_per_week')

# 3. Bar plot: Average visits by membership type
# Use: sns.barplot(data=gym, x='abonoment_type', y='visit_per_week')
